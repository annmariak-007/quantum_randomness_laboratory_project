# %%
pip install qiskit qiskit-aer matplotlib numpy scipy

# %%
# !git clone https://github.com/annmariak-007/quantum_randomness_laboratory_project.git

# %cd quantum_randomness_laboratory_project

# %%
# %run qrng.py

# %run statistics.py

# %run comparison.py

# %%
# %run histogram.py
